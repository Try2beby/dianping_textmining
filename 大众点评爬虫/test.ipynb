# %%
from mysqls import *

# create_table()
export_csv()

# %%
import requests
from main import DianpingScraper

url = "https://www.dianping.com/shop/l9qwmkX3FoD9tExc/review_all"
test = DianpingScraper(shop_id="l9qwmkX3FoD9tExc", page_end=1064)
html, error_msg = test.get_html_text(url=url)
if not error_msg:
    print(html)
# Out:
# <!DOCTYPE html>
# <head>
#
#     <!-- 新页头 -->
#     <title>“海底捞火锅(人民广场店)”的全部点评 - 上海美食 - 大众点评网</title>
#     <!--网页标题左侧显示-->
#     <link rel="icon" type="image/x-icon" href="//www.dpfile.com/app/pc-common/dp_favicon.a4af753914321c8e82e402e2b4be01d7.ico">
#     <!--收藏夹显示图标-->
#     <link rel="shortcut icon" type="image/x-icon" href="//www.dpfile.com/app/pc-common/dp_favicon.a4af753914321c8e82e402e2b4be01d7.ico">
#     <meta name="Keywords" content="海底捞火锅(人民广场店)评价, 海底捞火锅(人民广场店)好不好, 海底捞火锅(人民广场店)怎么样"/>
#     <meta name="Description" content="此商户已有15987条评价，想知道海底捞火锅(人民广场店)口碑好不好？服务怎么样？上海大众点评为您提供更丰富更真实的探店消费评价和最新的团购优惠活动体验打分，快来查看网友们的所有点评和实拍照片吧！"/>
#         <meta name="location" content="province=上海;city=上海"/>
#         <meta http-equiv="mobile-agent" content="format=xhtml; url=http://m.dianping.com/shop/l9qwmkX3FoD9tExc/review_all">
#     <!--1. 首先引入页头模块css，保证页头模块css在前，首先渲染 -->
# ...
